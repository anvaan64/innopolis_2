# %% [markdown]
# <a href="https://colab.research.google.com/github/anvaan64/innopolis_2/blob/main/Pandas_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.csv', index_col=0)
df2 = pd.read_csv('df2.csv')

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %% [markdown]
# df.plot.hist()
# df.plot.bar()
# df.plot.barh()
# df.plot.line()
# df.plot.area()
# df.plot.scatter()
# df.plot.box()
# df.plot.kde()
# df.plot.hexbin()
# df.plot.pie()

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist(edgecolor='w').autoscale(enable=True, axis='both', tight=True)

# 'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'

# %%
df1['A'].plot.hist(bins=30, edgecolor='w').autoscale(enable=True, axis='both', tight=True)

# %%
df1[['A','B']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'A'}>,
#         <AxesSubplot:title={'center':'B'}>]], dtype=object)

# %%
df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True);

# %%
df2.plot.line(y='a', figsize=(12,3), lw=3)
# Out:
# <AxesSubplot:>

# %%
df2.plot.line(y=['a','b', 'c'], figsize=(12,3), lw=3)
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.2);

# %%
df1.plot.scatter(x='A', y='B', alpha=0.4)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c='C', alpha=0.4)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm', alpha=0.4)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s= df1['C']*50, c='C', cmap='coolwarm', alpha=0.4)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.boxplot();

# %%
df2[['b','e']].boxplot(by='e', grid=False);

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df2[['b','e']].boxplot(by='e', grid=False);

# %%
df2[['a','e']].boxplot(by='e', grid=False);

# %%
df2['a'].plot.kde();
# kernel density estination

# %%
df1[['A','B']].plot.kde();

# %%
df2.plot.kde();

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df
# Out:
#             a         b
# 0   -0.577406 -0.433201
# 1    0.177545  0.378881
# 2   -0.941857  1.588422
# 3    1.330422 -0.762208
# 4   -0.824365  1.057925
# ..        ...       ...
# 995 -1.030488  0.566431
# 996 -1.373923 -0.742929
# 997 -0.049858  0.824127
# 998  1.392645  0.061474
# 999  1.422748 -0.271248
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a', y='b', gridsize=15)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
